# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
model = YOLO(f'yolov8n.pt')

# %%
model.train(data="./documents/data.yaml", imgsz=640, plots=True, task="detect", epochs=100, degrees=90, mosaic=0, fliplr=0)
# Out:
# New https://pypi.org/project/ultralytics/8.1.47 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196  Python-3.11.5 torch-2.1.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# ...

# %%
best_model = YOLO("./runs/detect/train8/weights/best.pt")

# %%
pred = best_model.predict(task="detect", source="./documents/test/images", conf=0.5, save=True)
# Out:
# image 1/41 d:\TestTasks\GagarinHack\documents\test\images\image_111.png: 640x480 1 passport_register_page, 270.7ms
# image 2/41 d:\TestTasks\GagarinHack\documents\test\images\image_13.png: 480x640 1 passport_register_page, 91.0ms
# image 3/41 d:\TestTasks\GagarinHack\documents\test\images\image_172.png: 640x480 1 drivers_back, 8.0ms
# image 4/41 d:\TestTasks\GagarinHack\documents\test\images\image_181.png: 640x480 1 drivers_back, 7.0ms
# image 5/41 d:\TestTasks\GagarinHack\documents\test\images\image_198.png: 640x480 1 drivers_front, 7.0ms
# image 6/41 d:\TestTasks\GagarinHack\documents\test\images\image_200.png: 640x480 1 drivers_front, 7.0ms
# image 7/41 d:\TestTasks\GagarinHack\documents\test\images\image_220.png: 640x480 1 drivers_front, 7.0ms
# image 8/41 d:\TestTasks\GagarinHack\documents\test\images\image_223.png: 384x640 1 drivers_back, 156.2ms
# image 9/41 d:\TestTasks\GagarinHack\documents\test\images\image_225.png: 640x480 1 drivers_front, 8.0ms
# ...
